# %%
import cv2
from matplotlib import pyplot as plt

# %% [markdown]
# # Задание 1

# %%
# 1. С помощью библиотеки OpenCV считайте изображение:

image = cv2.imread('/content/markus-winkler-wvii1ayGs3A-unsplash.jpg')

image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image_rgb)
plt.axis('off')  # Отключаем оси координат
plt.show()

# %%
# 2. Определите разрешение изображения.

height, width, _ = image_rgb.shape
print('Высота изображения в пикселях', height)
print('Ширина изображения в пикселях', width)
# Out:
# Высота изображения в пикселях 2666
# Ширина изображения в пикселях 3999

# %%
# 3. Определите интенсивность каналов R,G,B для пикселя, находящегося на пересечении 1360 строки и 1974 столбца матричного представления изображения.

image_rgb[1360][1974]
# Out:
# array([178,  79,  73], dtype=uint8)

# %% [markdown]
# # Задание 2

# %%
# 1. С помощью библиотеки OpenCV считайте изображение:

image = cv2.imread('/content/dan-lazar-Iw7mpSiYwgs-unsplash.jpg')

# 2. Преобразуйте в палитру RGB.
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image_rgb)
plt.axis('off')  # Отключаем оси координат
plt.show()

# %%
# 3. Выделите подматрицу пикселей, находящихся на пересечении строк в диапазоне от 1800 до 2289 включительно, и столбцов в диапазоне от 2690 до 3339 включительно, матричного представления изображения.

image_rgb = image_rgb[1800:2289, 2690:3339]

plt.imshow(image_rgb)
plt.axis('off')  # Отключаем оси координат
plt.show()

# %% [markdown]
# # Задание 3

# %%
# 1. С помощью библиотеки OpenCV считайте изображение:

image = cv2.imread('/content/danist-gIrvhDFuDn0-unsplash.jpg')

image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image_rgb)
plt.axis('off')  # Отключаем оси координат
plt.show()

# %%
# 2. Сожмите изображение до ширины 890, соблюдая пропорции исходного изображения. Важно: коэффициент отношения сторон при вычислениях не округляйте. Если высота не окажется целой, округлите значение до целого в меньшую сторону.

height, width, _ = image.shape

new_width = 890
new_height = int(height * (new_width/width))

print('Коэффициент отношения исходной ширины изображения к его высоте', width/height)
print('Высота полученного изображения', new_height)
# Out:
# Коэффициент отношения исходной ширины изображения к его высоте 1.7777777777777777
# Высота полученного изображения 500
